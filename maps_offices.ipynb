# %%
import folium
from folium.vector_layers import Circle

# %% [markdown]
# ## Map with the places of interest and the first company

# %%
# Create a map with the company
company_sun1=[37.3709977,-121.9235529]
map_sn1 = folium.Map(location = company_sun1, zoom_start = 13)

# %%
#Define the coordinates of the other places of interest
tech_company_PayPal = [37.375874679466456,-121.92306376202592]
design_1 = [37.37334604119023,-121.92193508148193]
design_2 = [37.3691219,-121.917411]
school = [37.36330687882652,-121.9127954630632]
party_1 = [37.37152348661807,-121.92232810486176]
party_2 = [37.371769553739405,-121.92226542378253]
vagan = [37.3607916,-121.8991962]
basket = [37.37696075439453,-121.922660827636723]
starbucks_1 = [37.371585845947266,-121.92254638671875]
starbucks_2 = [37.369186,-121.92045]
pet=[37.3813788,-121.8959331]
san_jose_airport=[-121.928927, 37.363803]

#Aggregate the markers to the map

folium.Marker(company_sun1, tooltip='Offices', popup = 'Offices', icon=folium.Icon(color="green", icon="suitcase", prefix="fa")).add_to(map_sn1)
folium.Marker(san_jose_airport, tooltip='Airport', popup = 'San José Airport', icon=folium.Icon(color="blue", icon="plane", prefix="fa")).add_to(map_sn1)
folium.Marker(tech_company_PayPal, tooltip='Tech comp', popup = 'Paypal', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sn1)
folium.Marker(design_1, tooltip='Design comp',popup = 'Kiskon Technologies', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sn1)
folium.Marker(design_2, tooltip='Design comp',popup = 'Konica Minolta Business Solutions', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sn1)
folium.Marker(school, tooltip='School',popup = 'Bachrodt Elementary School', icon=folium.Icon(color="blue", icon="pencil", prefix="fa")).add_to(map_sn1)
folium.Marker(party_1, tooltip='Nightlife spot',popup = 'Doubletree Pool', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sn1)
folium.Marker(party_2, tooltip='Nightlife spot',popup = 'Lobby Lounge & Bar', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sn1)
folium.Marker(vagan, tooltip='Vegan restaurant',popup = "Brother Baby's BBQ", icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")).add_to(map_sn1)
folium.Marker(basket, tooltip='Basketball court',popup = 'eBay Inc. Basketball Court', icon=folium.Icon(color="blue", icon="futbol-o", prefix="fa")).add_to(map_sn1)
folium.Marker(starbucks_1,tooltip='Starbucks', popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sn1)
folium.Marker(starbucks_2, tooltip='Starbucks',popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sn1)
folium.Marker(pet, tooltip= 'Pet hairdresser',popup = 'Banfield Pet Hospital', icon=folium.Icon(color="blue", icon="heartbeat", prefix="fa")).add_to(map_sn1)


c= Circle(location=[37.3709977,-121.9235529], radius=2000, color="blue")
c.add_to(map_sn1)

map_sn1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Most of the spots are nearer than 2km from the office

# %% [markdown]
# ## Map with the places of interest and the second company

# %%
# Define the map and the company's coordinates
company_sj1=[37.37027,-121.924053]
map_sj1 = folium.Map(location = company_sj1, zoom_start = 13)

# %%
#Define the coordinates of the other interest spots
tech_company_1 = [37.370972648019674,-121.92549178587224]
tech_company_2 = [37.36947,-121.92351]
tech_company_3 = [37.37114012,-121.92559373]
design_1 = [37.3672899,-121.916]
school = [37.388926007147695,-121.90186142921448]
party_1 = [37.37124135626228,-121.91972331072563]
party_2 = [37.371769553739405,-121.92226542378253]
party_3 = [37.37152348661807,-121.92232810486176]
vegan = [37.3607916,-121.8991962]
basket = [37.37696075439453,-121.92266082763672]
starbucks_1 = [37.371585845947266,-121.92254638671875]
starbucks_2 = [37.369186,-121.92045]
pet=[37.36269,-121.95201]
san_jose_airport=[-121.928927, 37.363803]


#Aggregate the markers to the map

folium.Marker(company_sj1, tooltip='Offices', popup = 'Offices', icon=folium.Icon(color="green", icon="suitcase", prefix="fa")).add_to(map_sj1)
folium.Marker(san_jose_airport, tooltip='Airport', popup = 'San José Airport', icon=folium.Icon(color="blue", icon="plane", prefix="fa")).add_to(map_sj1)

folium.Marker(tech_company_1, tooltip='Tech comp', popup = 'SourceN HQ', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj1)
folium.Marker(tech_company_2, tooltip='Tech comp', popup = 'FixStream', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj1)
folium.Marker(tech_company_3, tooltip='Tech comp', popup = 'DataTech Labs Data Recovery', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj1)

folium.Marker(design_1, tooltip='Design comp',popup = 'Watry Design', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sj1)

folium.Marker(school, tooltip='School',popup = 'Orchard Elementary School', icon=folium.Icon(color="blue", icon="pencil", prefix="fa")).add_to(map_sj1)

folium.Marker(party_1, tooltip='Nightlife spot',popup = 'Zone 8 Sports Bar & Grill', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj1)
folium.Marker(party_2, tooltip='Nightlife spot',popup = 'Lobby Lounge & Bar', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj1)
folium.Marker(party_3, tooltip='Nightlife spot',popup = 'Doubletree Pool', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj1)

folium.Marker(vegan, tooltip='Vegan restaurant',popup = "Brother Baby's BBQ", icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")).add_to(map_sj1)

folium.Marker(basket, tooltip='Basketball court',popup = 'eBay Inc. Basketball Court', icon=folium.Icon(color="blue", icon="futbol-o", prefix="fa")).add_to(map_sj1)

folium.Marker(starbucks_1,tooltip='Starbucks', popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj1)
folium.Marker(starbucks_2, tooltip='Starbucks',popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj1)

folium.Marker(pet, tooltip= 'Pet hairdresser',popup = ' Ohana Kennels', icon=folium.Icon(color="blue", icon="heartbeat", prefix="fa")).add_to(map_sj1)

c= Circle(location=[37.3709977,-121.9235529], radius=2000, color="blue")
c.add_to(map_sj1)

map_sj1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The school, the vegan restarant and the pet hairdresser are too far away from the office

# %% [markdown]
# ## Map with the places of interest and the third company

# %%
# Create the map
company_sj2=[37.371088,-121.925355]
map_sj2 = folium.Map(location = company_sj2, zoom_start = 13)

# %%
#Define the coordinates of the markers
tech_company_1 = [37.370972648019674,-121.92549178587224]
tech_company_2 = [37.37114012,-121.92559373]
design_1 = [37.37334604119023,-121.92193508148193]
school = [37.36330687882652,-121.9127954630632]
party_1 = [37.371769553739405,-121.92226542378253]
party_2 = [37.37152348661807,-121.92232810486176]
vegan = [37.3607916,-121.8991962]
basket = [37.37696075439453,-121.92266082763672]
starbucks_1 = [37.371585845947266,-121.92254638671875]
pet=[37.36273680000001,-121.9526368]
san_jose_airport=[-121.928927, 37.363803]

#Aggregate the markers

folium.Marker(company_sj2, tooltip='Offices', popup = 'Offices', icon=folium.Icon(color="green", icon="suitcase", prefix="fa")).add_to(map_sj2)
folium.Marker(san_jose_airport, tooltip='Airport', popup = 'San José Airport', icon=folium.Icon(color="blue", icon="plane", prefix="fa")).add_to(map_sj2)

folium.Marker(tech_company_1, tooltip='Tech comp', popup = 'SourceN HQ', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj2)
folium.Marker(tech_company_2, tooltip='Tech comp', popup = 'DataTech Labs Data Recovery', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj2)

folium.Marker(design_1, tooltip='Design comp',popup = 'Kiskon Technologies', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sj2)

folium.Marker(school, tooltip='School',popup = 'Bachrodt Elementary School', icon=folium.Icon(color="blue", icon="pencil", prefix="fa")).add_to(map_sj2)

folium.Marker(party_1, tooltip='Nightlife spot',popup = 'Doubletree Pool', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj2)
folium.Marker(party_2, tooltip='Nightlife spot',popup = 'Lobby Lounge & Bar', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj2)

folium.Marker(vegan, tooltip='Vegan restaurant',popup = "Brother Baby's BBQ", icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")).add_to(map_sj2)

folium.Marker(basket, tooltip='Basketball court',popup = 'eBay Inc. Basketball Court', icon=folium.Icon(color="blue", icon="futbol-o", prefix="fa")).add_to(map_sj2)

folium.Marker(starbucks_1,tooltip='Starbucks', popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj2)

folium.Marker(pet, tooltip= 'Pet hairdresser',popup = 'Bay Area K9 Association LLC.', icon=folium.Icon(color="blue", icon="heartbeat", prefix="fa")).add_to(map_sj2)

c= Circle(location=[37.3709977,-121.9235529], radius=2000, color="blue")
c.add_to(map_sj2)

map_sj2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Most of the places of interest are close to the office

# %% [markdown]
# ## Map with the places of interest and the fourth company

# %%
# Create the map
company_sj3=[37.3709977,-121.9235529]
map_sj3 = folium.Map(location = company_sj3, zoom_start = 13)

# %%
#Define las coordenadas que queremos que sean nuestros marcadores
tech_company_1 = [37.36947,-121.92351]
tech_company_2 = [37.370972648019674,-121.92549178587224]
tech_company_3 = [37.37114012,-121.92559373]
design_1 = [37.37334604119023,-121.92193508148193]
school = [37.36330687882652,-121.9127954630632]
party_1 = [37.37152348661807,-121.92232810486176]
party_2 = [ 37.371769553739405,-121.92226542378253]
vegan = [37.3607916,-121.8991962]
basket = [37.37696075439453,-121.92266082763672]
starbucks_1 = [37.371585845947266,-121.92254638671875]
starbucks_2 = [37.369186,-121.92045]
pet=[37.36269,-121.95201]
san_jose_airport=[-121.928927, 37.363803]

#Add the interest points to the map

folium.Marker(company_sj3, tooltip='Offices', popup = 'Offices', icon=folium.Icon(color="green", icon="suitcase", prefix="fa")).add_to(map_sj3)
folium.Marker(san_jose_airport, tooltip='Airport', popup = 'San José Airport', icon=folium.Icon(color="blue", icon="plane", prefix="fa")).add_to(map_sj3)

folium.Marker(tech_company_1, tooltip='Tech comp', popup = 'FixStream', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj3)
folium.Marker(tech_company_2, tooltip='Tech comp', popup = 'SourceN HQ', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj3)
folium.Marker(tech_company_3, tooltip='Tech comp', popup = 'DataTech Labs Data Recovery', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj3)

folium.Marker(design_1, tooltip='Design comp',popup = 'Kiskon Technologies', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sj3)

folium.Marker(school, tooltip='School',popup = 'Bachrodt Elementary School', icon=folium.Icon(color="blue", icon="pencil", prefix="fa")).add_to(map_sj3)

folium.Marker(party_1, tooltip='Nightlife spot',popup = 'Doubletree Pool', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj3)
folium.Marker(party_2, tooltip='Nightlife spot',popup = 'Lobby Lounge & Bar', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj3)

folium.Marker(vegan, tooltip='Vegan restaurant',popup = "Brother Baby's BBQ", icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")).add_to(map_sj3)

folium.Marker(basket, tooltip='Basketball court',popup = 'eBay Inc. Basketball Court', icon=folium.Icon(color="blue", icon="futbol-o", prefix="fa")).add_to(map_sj3)

folium.Marker(starbucks_1,tooltip='Starbucks', popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj3)
folium.Marker(starbucks_2, tooltip='Starbucks',popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj3)

folium.Marker(pet, tooltip= 'Pet hairdresser',popup = ' Ohana Kennels', icon=folium.Icon(color="blue", icon="heartbeat", prefix="fa")).add_to(map_sj3)

c= Circle(location=[37.3709977,-121.9235529], radius=2000, color="blue")
c.add_to(map_sj3)

map_sj3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The places of interest are almost the same as in the previous office

# %% [markdown]
# ## Map with the places of interest and the fifth company

# %%
# Create the map
company_sj4=[37.3706126,-121.9219538]
map_sj4 = folium.Map(location = company_sj4, zoom_start = 13)

# %%
#Define the coordinates of the spots in the map
tech_company_1 = [37.369302000000005,-121.92127099999999]
tech_company_2 = [37.36957044583222,-121.921677387159]
tech_company_3 = [37.3695173976203,-121.92133577652343]
tech_company_4 = [37.36947,-121.92351]
design_1 = [37.37334604119023,-121.92193508148193]
design_2 = [37.3691219,-121.917411]
school = [37.36330687882652,-121.9127954630632]
party_1 = [37.37124135626228,-121.91972331072563]
party_2 = [37.37152348661807,-121.92232810486176]
party_3 = [37.371532546100354,-121.9220969824811]
vegan = [37.385706,-121.908328]
basket_1 = [7.37696075439453,-121.92266082763672]
basket_2= [37.36441421508789,-121.91527557373047]
starbucks_1 = [37.371585845947266,-121.92254638671875]
starbucks_2 = [37.369186,-121.92045]
pet=[37.3813788,-121.8959331]
san_jose_airport=[-121.928927, 37.363803]

#Add the markers to the map

folium.Marker(company_sj4, tooltip='Offices', popup = 'Offices', icon=folium.Icon(color="green", icon="suitcase", prefix="fa")).add_to(map_sj4)
folium.Marker(san_jose_airport, tooltip='Airport', popup = 'San José Airport', icon=folium.Icon(color="blue", icon="plane", prefix="fa")).add_to(map_sj4)

folium.Marker(tech_company_1, tooltip='Tech comp', popup = 'PlayPhone, Inc.', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj4)
folium.Marker(tech_company_2, tooltip='Tech comp', popup = 'River Meadow Software', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj4)
folium.Marker(tech_company_3, tooltip='Tech comp', popup = 'Robin Systems', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj4)
folium.Marker(tech_company_3, tooltip='Tech comp', popup = 'FixStream', icon=folium.Icon(color="blue", icon="building-o", prefix="fa")).add_to(map_sj4)

folium.Marker(design_1, tooltip='Design comp',popup = 'Kiskon Technologies', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sj4)
folium.Marker(design_1, tooltip='Design comp',popup = 'Konica Minolta Business Solutions', icon=folium.Icon(color="blue", icon="pencil-square-o", prefix="fa")).add_to(map_sj4)

folium.Marker(school, tooltip='School',popup = 'Bachrodt Elementary School', icon=folium.Icon(color="blue", icon="pencil", prefix="fa")).add_to(map_sj4)

folium.Marker(party_1, tooltip='Nightlife spot',popup = 'Zone 8 Sports Bar & Grill', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj4)
folium.Marker(party_2, tooltip='Nightlife spot',popup = 'Doubletree Pool', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj4)
folium.Marker(party_3, tooltip='Nightlife spot',popup = 'Fortyeight at DoubleTree', icon=folium.Icon(color="blue", icon="music", prefix="fa")).add_to(map_sj4)

folium.Marker(vegan, tooltip='Vegan restaurant',popup = "Vegefarm", icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")).add_to(map_sj4)

folium.Marker(basket, tooltip='Basketball court',popup = 'eBay Inc. Basketball Court', icon=folium.Icon(color="blue", icon="futbol-o", prefix="fa")).add_to(map_sj4)
folium.Marker(basket, tooltip='Basketball court',popup = 'Brocade Courts', icon=folium.Icon(color="blue", icon="futbol-o", prefix="fa")).add_to(map_sj4)

folium.Marker(starbucks_1,tooltip='Starbucks', popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj4)
folium.Marker(starbucks_2, tooltip='Starbucks',popup = 'Starbucks', icon=folium.Icon(color="blue", icon="coffee", prefix="fa")).add_to(map_sj4)

folium.Marker(pet, tooltip= 'Pet hairdresser',popup = 'Banfield Pet Hospital', icon=folium.Icon(color="blue", icon="heartbeat", prefix="fa")).add_to(map_sj4)

c= Circle(location=[37.3709977,-121.9235529], radius=2000, color="blue")
c.add_to(map_sj4)

map_sj4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The places of interest are not too far away from the office

# %% [markdown]
# ---------

# %% [markdown]
# ## Choose the better positioned office
# **1st.**
# Has 1 tech company at 500m, it is near 2 design studios at 300m and 500m, a school at 1,3 km, 2 places to go to party, 1 basketball court, has 2 starbucks at 100m and 300m
#
# **2nd.**
# Has near 3 tech startups at 100m, 1 design studio at 700m, has 2 places to go to party at 300m and 200m, 1 baskeball court at 700m, has two starbucks at 100m and 300m
#
# From this two I select the first one because it has two design studios nearer than the second one, the school is also nearer, as well as the basketball court and the places to go to party.
#
#  **3rd.**
# Has two tech startups very close at 17m and 21m, and the pet hairdresser at 2,6m.
#
# Between the third and first offices I select the first as althout the tech companies are further away, the first company has a better position regarding all the other requisites.
#
#  **4th.**
# Has 3 tech startups at 100m, and has equal position for the school, nighlife spots, basketball court and starbucks than the first office.
#
# Between the first and the fourth offices I select the fourth as it has three tech startups very close to it.
#
# **5th.**
# Has 4 tech startups at 100m, has 2 design studios at 300m and 400m, has a school at 1km, 3 nighlife spots at 100m and 200m, two basketball courts near, 2 starbucks at 100m and 200m.
#
# Between the fourth and the fifth, I selected the **5th** one as it is better positioned regarding all the requisites, especially the tech startups.
